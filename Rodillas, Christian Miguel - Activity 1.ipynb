# %%
#20 points per quiz / Total:100
Q_Total = 100

Q1 = int(input("What is the first quiz score? "))
Q2 = int(input("What is the second quiz score? "))
Q3 = int(input("What is the third quiz score? "))
Q4 = int(input("What is the fourth quiz score? "))
Q5 = int(input("What is the fifth quiz score? "))

Q_Total = Q1 + Q2 + Q3 + Q4 + Q5

AQ = Q_Total / 5

print("The average score of quizzes is " + str(AQ))

Q_Perc = Q_Total
print("The percent score is " + str(Q_Perc) + "%")
# Out:
# What is the first quiz score? 17
# What is the second quiz score? 18
# What is the third quiz score? 19
# What is the fourth quiz score? 20
# What is the fifth quiz score? 20
# The average score of quizzes is 18.8
# The percent score is 94%

# %%
#10 points per activity / Total: 40
A1 = int(input("What is the first assignment score? "))
A2 = int(input("What is the second assignment score? "))

S1 = int(input("What is the first seatwork score? "))
S2 = int(input("What is the second seatwork score? "))

A_Total = A1 + A2 + S1 + S2
CS = A_Total / 4 

print("The average score of quizzes is " + str(CS))

A_Perc = A_Total * 2.5

print("The percent score is " + str(A_Perc) + "%")
# Out:
# What is the first assignment score? 10
# What is the second assignment score? 10
# What is the first seatwork score? 9
# What is the second seatwork score? 8
# The average score of quizzes is 9.25
# The percent score is 92.5%

# %%
#out of 100 
M1 = int(input("What is major exam score? "))
# Out:
# What is major exam score? 96

# %%
Grade = (M1*.50) + (Q_Perc*.40) + (A_Perc*.10)

print(Grade)
# Out:
# 94.85
