# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Create a simulated non linear

# %%
np.random.seed(777)

# %%
X = np.sort(5 * np.random.rand(80, 1), axis=0) # ind variable
y = np.sin(X) * 2 + np.cos(X) +np.random.randn(80, 1) * 0.5 # dep variable non linear rel with noise

# %%
print("Sample data points")
for i in range(5):
    print(f"X: {X[i][0]:.3f}, y: {y[i][0]:.3f}")
# Out:
# Sample data points
# X: 0.067, y: 0.416
# X: 0.082, y: 1.669
# X: 0.135, y: 1.219
# X: 0.310, y: 1.371
# X: 0.398, y: 1.579

# %%
y = y.ravel()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"\nData split: {len(X_train)} training samples, {len(X_test)} testing samples.")
# Out:
# Data split: 56 training samples, 24 testing samples.

# %%
tree_model = DecisionTreeRegressor(max_depth=5, random_state=42)
tree_model.fit(X_train, y_train)

print("Decision Tree model training complete.")
# Out:
# Decision Tree model training complete.

# %%
y_pred = tree_model.predict(X_test)

print("Predictions made successfully.")
print("Sample predictions:")

for i in range(min(5, len(y_test))):
    print(f"  Actual: {y_test[i]:.2f}, Predicted: {y_pred[i]:.2f}")

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("\nModel Evaluation:")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R²): {r2:.2f}")
# Out:
# Predictions made successfully.
# Sample predictions:
#   Actual: 1.28, Predicted: 1.63
#   Actual: 0.42, Predicted: 1.42
#   Actual: 2.35, Predicted: 1.68
#   Actual: 1.73, Predicted: 1.63
#   Actual: 2.91, Predicted: 2.43
#
# Model Evaluation:
# Mean Squared Error (MSE): 0.27
# R-squared (R²): 0.91

# %%
X_sorted = np.sort(X.flatten())
X_sorted = X_sorted.reshape(-1, 1)

y_pred_curve = tree_model.predict(X_sorted)

plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X_sorted, y_pred_curve, color='red', linewidth=2, label='Decision Tree Fit')
plt.title('Decision Tree Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

print("\nVisualization complete. The plot shows the original data points and the step-like prediction curve from the Decision Tree.")
# Out:
# Visualization complete. The plot shows the original data points and the step-like prediction curve from the Decision Tree.
